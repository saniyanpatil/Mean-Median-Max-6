# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyanpatil/Mean-Median-Max-6/blob/main/ex6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
image = cv2.imread('/content/LUCAA.webp', cv2.IMREAD_GRAYSCALE)

# Mean Filter (Blurring)
mean_filtered = cv2.blur(image, (5, 5))

# Max Filter (Applying a maximum filter)
max_filtered = cv2.dilate(image, np.ones((5, 5), np.uint8))

# Median Filter (Denoising)
median_filtered = cv2.medianBlur(image, 5)

# Show the original and processed images
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1), plt.imshow(image, cmap='gray'), plt.title('Original')
plt.subplot(2, 2, 2), plt.imshow(mean_filtered, cmap='gray'), plt.title('Mean Filter')
plt.subplot(2, 2, 3), plt.imshow(max_filtered, cmap='gray'), plt.title('Max Filter')
plt.subplot(2, 2, 4), plt.imshow(median_filtered, cmap='gray'), plt.title('Median Filter')
plt.show()
